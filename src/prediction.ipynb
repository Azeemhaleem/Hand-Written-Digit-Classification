# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# %%
model = load_model('../models/mnist_tensorflow_prediction_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
input_image = '../inputs/images.png'

image = cv2.imread(input_image)
print(image.shape)
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image = cv2.resize(image, (28, 28))
image = image.astype("float32") / 255.0
image = image.reshape(28, 28, 1)
image = np.expand_dims(image, axis=0) 

prediction = model.predict(image)
print(prediction)

img_prediction = model.predict(image)
prediction = np.argmax(img_prediction)

print(prediction)
# Out:
# (230, 219, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# [[1.1207271e-07 3.3370744e-09 2.9836436e-08 2.1760191e-06 4.0277993e-07
#   3.4372256e-08 5.2860820e-11 1.3882557e-05 5.3085688e-07 9.9998283e-01]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 9
