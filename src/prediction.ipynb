# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# %%
model = load_model('../models/mnist_tensorflow_prediction_model.keras')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
input_image = '../data/raw/mnist/2/25.png'

image = cv2.imread(input_image)
print(image.shape)
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image = cv2.resize(image, (28, 28))
image = image.astype("float32") / 255.0
image = image.reshape(28, 28, 1)
image = np.expand_dims(image, axis=0) 

prediction = model.predict(image)
print(prediction)

img_prediction = model.predict(image)
prediction = np.argmax(img_prediction)

print(prediction)
# Out:
# (32, 32, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# [[1.5985028e-05 2.2012140e-05 9.9941993e-01 5.2522350e-04 8.4076621e-09
#   2.6161445e-08 5.6801621e-08 9.6833318e-08 1.6623750e-05 8.2728988e-08]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 2
